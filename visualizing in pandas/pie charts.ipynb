# %%
import pandas as pd
import numpy as np

# %%
games = pd.read_csv('https://andybek.com/pandas-games')

# %%
games.head()
# Out:
#                              Name Platform    Year    Genre  \
# 0              Kinect Adventures!     X360  2010.0     Misc
# 1              Grand Theft Auto V      PS3  2013.0   Action
# 2              Grand Theft Auto V     X360  2013.0   Action
# 3  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4         Call of Duty: Black Ops     X360  2010.0  Shooter
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1    Take-Two Interactive      7.01      9.27      0.97         4.14
# 2    Take-Two Interactive      9.63      5.31      0.06         1.38
# 3              Activision      9.03      4.28      0.13         1.32
# 4              Activision      9.67      3.73      0.11         1.13
#
#    Global_Sales
# 0         21.82
# 1         21.40
# 2         16.38
# 3         14.76
# 4         14.64

# %%
# what is the market share for eaxh platform in Na

# %%
games.groupby('Platform').NA_Sales.agg('sum').plot(kind='pie', figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='NA_Sales'>

# %%
games.groupby('Platform').JP_Sales.agg('sum').plot(kind='pie', figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='JP_Sales'>

# %%
temp = games.loc[:,['NA_Sales','JP_Sales','Platform']]

# %%
temp.groupby('Platform').agg('sum').plot(kind='pie', subplots = True,  autopct='%1.1f%%',figsize=(20,20))
# Out:
# array([<AxesSubplot:ylabel='NA_Sales'>, <AxesSubplot:ylabel='JP_Sales'>],
#       dtype=object)
