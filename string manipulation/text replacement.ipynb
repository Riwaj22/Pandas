# %%
import numpy as np
import pandas as pd

# %%
boston = pd.read_csv(r"C:\Users\97798\Desktop\The Ultimate Pandas Bootcamp Advanced Python Data Analysis\[TutsNode.com] - The Ultimate Pandas Bootcamp Advanced Python Data Analysis\Sources\2017BostonMarathonTop1000.csv")

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN      KE       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR      US       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN      JP       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA      US       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN      KE       2:12:35
#
#    Overall  Gender Years Ran last name first name
# 0        1       1       NaN     Kirui  Geoffrey
# 1        2       2       NaN      Rupp   Galen
# 2        3       3       NaN     Osako   Suguru
# 3        4       4       NaN    Biwott   Shadrack
# 4        5       5      2015    Chebet     Wilson

# %%
boston.sample(10)
# Out:
#                          Name  Age M/F           City State Country  \
# 277          Haughton, Daniel   27   M   Philadelphia    PA      US
# 102                Nurse, Ian   39   M      Brookline    MA      US
# 81     Ellenberger, Michael P   25   M        Chicago    IL      US
# 977        Guthals, Nathaniel   26   M  Overland Park    KS      US
# 600         Peterson, Alex A.   33   M   Falls Church    VA      US
# 432  Bin Alias, Mohd Syahidan   29   M      Shah Alam   NaN      MA
# 793         Fernandez, Nestor   28   M       Santiago   NaN      CH
# 536           Looi, Alexander   28   M     Burlington    VT      US
# 426        Couture, Nathaniel   36   M    Fredericton    NB      CA
# 841      Arbaugh, Benjamin M.   20   M          Davis    CA      US
#
#     Official Time  Overall  Gender  Years Ran    last name     first name
# 277       2:43:38      278     253       2016     Haughton         Daniel
# ...

# %%
boston['M/F'] = boston['M/F'].str.replace('M', 'Male')

# %%
boston['M/F'] = boston['M/F'].str.replace('F', 'Female')

# %%
boston['M/F'].value_counts()
# Out:
# Male      944
# Female     56
# Name: M/F, dtype: int64

# %%
boston.Country = boston.Country.str.replace('US', 'United States', case=False)

# %%
boston.Country.value_counts()
# Out:
# United States    744
# CA                63
# GB                30
# BR                13
# FR                11
# JP                10
# ME                10
# CO                 9
# CH                 8
# SU                 8
# GE                 8
# KE                 8
# ES                 7
# AU                 7
# CR                 7
# ET                 5
# TW                 5
# PE                 4
# IT                 4
# DE                 4
# PO                 4
# IR                 4
# DO                 3
# HK                 3
# NE                 3
# NZ                 2
# RU                 2
# GU                 2
# NO                 2
# AR                 1
# SI                 1
# RS                 1
# BD                 1
# PH                 1
# MA                 1
# PA                 1
# BE                 1
# ZI                 1
# SL                 1
# Name: Country, dtype: int64
