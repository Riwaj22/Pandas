# %%
import numpy as np
import pandas as pd

# %%
boston = pd.read_csv(r"C:\Users\97798\Desktop\The Ultimate Pandas Bootcamp Advanced Python Data Analysis\[TutsNode.com] - The Ultimate Pandas Bootcamp Advanced Python Data Analysis\Sources\2017BostonMarathonTop1000.csv")

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran
# 0        1       1       NaN
# 1        2       2       NaN
# 2        3       3       NaN
# 3        4       4       NaN
# 4        5       5      2015

# %%
boston['last name']= boston.Name.str.split(', ').str.get(0)

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran last name
# 0        1       1       NaN     Kirui
# 1        2       2       NaN      Rupp
# 2        3       3       NaN     Osako
# 3        4       4       NaN    Biwott
# 4        5       5      2015    Chebet

# %%
boston['first name']= boston.Name.str.split(', ').str.get(1)

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran last name first name
# 0        1       1       NaN     Kirui  Geoffrey
# 1        2       2       NaN      Rupp   Galen
# 2        3       3       NaN     Osako   Suguru
# 3        4       4       NaN    Biwott   Shadrack
# 4        5       5      2015    Chebet     Wilson

# %%
boston.Country = boston.Country.str.slice(0,2,1)

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN      KE       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR      US       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN      JP       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA      US       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN      KE       2:12:35
#
#    Overall  Gender Years Ran last name first name
# 0        1       1       NaN     Kirui  Geoffrey
# 1        2       2       NaN      Rupp   Galen
# 2        3       3       NaN     Osako   Suguru
# 3        4       4       NaN    Biwott   Shadrack
# 4        5       5      2015    Chebet     Wilson

# %%
boston[boston.Country == 'IT'].Name
# Out:
# 56            Boudalia, Said Sr.
# 156           Achmuller, Hermann
# 792    Consolandi, Paolo Giorgio
# 922         Zompanti, Alessandro
# Name: Name, dtype: object

# %%
boston[(boston.Name.str.contains('Will')) & (boston.Age>=45)]
# Out:
#                   Name  Age M/F           City State Country Official Time  \
# 93      Vanos, William   45   M        Orlando    FL      US       2:34:40
# 526      Swenson, Will   45   M        Andover    MA      US       2:49:10
# 814  Williamson, David   49   M         Sutton   NaN      GB       2:53:46
# 892       Rivera, Will   46   M  Elizabethtown    KY      US       2:54:53
#
#      Overall  Gender  Years Ran   last name first name
# 93        94      84        NaN       Vanos    William
# 526      527     490  2015:2016     Swenson       Will
# 814      815     768        NaN  Williamson      David
# 892      893     843        NaN      Rivera       Will

# %%
boston.Age.hist()
# Out:
# <AxesSubplot:>
