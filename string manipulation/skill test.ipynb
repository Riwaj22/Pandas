# %%
import numpy as np
import pandas as pd

# %%
boston = pd.read_csv(r"C:\Users\97798\Desktop\The Ultimate Pandas Bootcamp Advanced Python Data Analysis\[TutsNode.com] - The Ultimate Pandas Bootcamp Advanced Python Data Analysis\Sources\2017BostonMarathonTop1000.csv")

# %%
boston.head()
# Out:
#                 Name  Age   M/F           City State        Country  \
# 0   Kirui, Geoffrey    24  Male       Keringet   NaN             KE
# 1     Rupp, Galen      30  Male       Portland    OR  United States
# 2    Osako, Suguru     25  Male   Machida-City   NaN             JP
# 3   Biwott, Shadrack   32  Male  Mammoth Lakes    CA  United States
# 4     Chebet, Wilson   31  Male       Marakwet   NaN             KE
#
#   Official Time  Overall  Gender Years Ran last name first name
# 0       2:09:37        1       1       NaN     Kirui  Geoffrey
# 1       2:09:58        2       2       NaN      Rupp   Galen
# 2       2:10:28        3       3       NaN     Osako   Suguru
# 3       2:12:08        4       4       NaN    Biwott   Shadrack
# 4       2:12:35        5       5      2015    Chebet     Wilson

# %%
import re

# %%
boston['Hour'] = boston['Official Time'].str.split(':').str.get(0)

# %%
boston['Minute'] = boston['Official Time'].str.split(':').str.get(1)

# %%
boston['Second'] = boston['Official Time'].str.split(':').str.get(2)

# %%
boston['Hour'].dtype
# Out:
# dtype('int32')

# %%
boston['Second'] = boston['Second'].astype(int)

# %%
boston['Minute'] = boston['Minute'].astype(int)

# %%
boston['Total'] = boston['Second'] + boston['Minute'] * 60 + boston['Hour'] * 60 * 60

# %%
boston
# Out:
#                     Name  Age   M/F           City State        Country  \
# 0       Kirui, Geoffrey    24  Male       Keringet   NaN             KE
# 1         Rupp, Galen      30  Male       Portland    OR  United States
# 2        Osako, Suguru     25  Male   Machida-City   NaN             JP
# 3       Biwott, Shadrack   32  Male  Mammoth Lakes    CA  United States
# 4         Chebet, Wilson   31  Male       Marakwet   NaN             KE
# ..                   ...  ...   ...            ...   ...            ...
# 995         Larosa, Mark   38  Male  North Andover    MA  United States
# 996  Williamson, Jerry A   43  Male        Raleigh    NC  United States
# 997      Mccue, Daniel T   40  Male      Arlington    MA  United States
# 998         Larosa, John   35  Male        Danbury    CT  United States
# 999       Sanchez, Sam R   35  Male       Santa Fe    NM  United States
#
#     Official Time  Overall  Gender  Years Ran   last name first name  Hour  \
# ...
