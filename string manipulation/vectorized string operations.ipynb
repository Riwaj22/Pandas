# %%
import numpy as np
import pandas as pd

# %%
boston_url = 'https://anybek.com/pandas-marathon'

# %%
boston = pd.read_csv(r"C:\Users\97798\Desktop\The Ultimate Pandas Bootcamp Advanced Python Data Analysis\[TutsNode.com] - The Ultimate Pandas Bootcamp Advanced Python Data Analysis\Sources\2017BostonMarathonTop1000.csv")

# %%
boston
# Out:
#                     Name  Age M/F           City State Country Official Time  \
# 0       Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1         Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2        Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3       Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4         Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
# ..                   ...  ...  ..            ...   ...     ...           ...
# 995         Larosa, Mark   38   M  North Andover    MA     USA       2:56:06
# 996  Williamson, Jerry A   43   M        Raleigh    NC     USA       2:56:06
# 997      Mccue, Daniel T   40   M      Arlington    MA     USA       2:56:06
# 998         Larosa, John   35   M        Danbury    CT     USA       2:56:07
# 999       Sanchez, Sam R   35   M       Santa Fe    NM     USA       2:56:08
#
#      Overall  Gender  Years Ran
# 0          1       1        NaN
# 1          2       2        NaN
# 2          3       3        NaN
# 3          4       4        NaN
# 4          5       5       2015
# ..       ...     ...        ...
# 995      996     940  2015:2016
# 996      997     941       2015
# 997      998     942        NaN
# 998      999     943        NaN
# 999     1000     944        NaN
#
# [1000 rows x 10 columns]

# %%
boston.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           1000 non-null   object
#  1   Age            1000 non-null   int64
#  2   M/F            1000 non-null   object
#  3   City           1000 non-null   object
#  4   State          807 non-null    object
#  5   Country        1000 non-null   object
#  6   Official Time  1000 non-null   object
#  7   Overall        1000 non-null   int64
#  8   Gender         1000 non-null   int64
#  9   Years Ran      315 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 430.2 KB

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran
# 0        1       1       NaN
# 1        2       2       NaN
# 2        3       3       NaN
# 3        4       4       NaN
# 4        5       5      2015

# %%
n = boston.Name

# %%
n = sorted(boston.Name)

# %%
n
# Out:
# [' Kirui, Geoffrey ',
#  'Abdirahman, Abdi',
#  'Accioly, Marcelo P',
#  'Achmuller, Hermann',
#  'Acosta, Oscar J. Sr.',
#  'Adams, Craig',
#  'Adams, William C',
#  'Aga, Ruti',
#  'Aghegnehu, Abinazer',
#  'Agnew, Jeremy',
#  'Aguila, Nick',
#  'Aitken, Miles',
#  'Alban, Bradley',
#  'Albarracin, Diego R Sr.',
#  'Aldrich, Micah J',
#  'Allan, Kirsten N',
#  'Allen, Cale',
#  'Allen, Christopher',
#  'Alonso, Julian R.',
#  'Alvarez, Recio',
#  'Ames, Tyler',
#  'Anderson, Aaron L',
#  'Anderson, Mallory E',
#  'Andre, Stephanie',
#  'Anfimov, Maksim',
#  'Angus, Mark E',
#  'Anis, Michael',
#  'Aono, Hiromasa',
#  'Appman, Timothy G',
#  'Arai, Tatsuya',
#  'Aramaki, Yuzo',
#  'Arbaugh, Benjamin M.',
#  'Arend, Robert J.',
#  'Arias Navarro, Aroon H.',
#  "Arthur, D'Ann E",
#  'Ash, Alan',
#  'Ashby, Robert S',
#  'Ashe, Eric',
#  'Ashford, Christopher A',
#  'Atkins, Benjamin',
#  'Atkins, Esther',
#  'Atwater, Beau',
#  'Aubut, Xavier',
#  'Austin, Jake',
#  'Autrey, Jonathan',
#  'Avalos, Anthony B.',
#  'Avalos, Ray A Jr.',
#  'Ayr, Jason M.',
#  'Baasch, Douglas',
#  'Baek, James',
#  'Baghdadi, Hossein',
#  'Bain, Christopher',
#  'Bak, Frederik',
#  'Baldwin, Douglas R.',
#  'Baranowski, Miroslaw',
#  'Bardeesy, Rami',
#  'Bardey, Jonathan A',
#  'Battoo, Christopher',
#  'Batzel, Dane',
#  'Baysa, Atsede',
#  'Bazeille, Sebastien',
#  'Beamer, Matthew M',
#  'Beck, Owen',
#  'Becker, Aaron',
#  'Becker, Scott',
#  'Beckett, Ryan',
#  'Bedbury, Nick',
#  'Bedoya, David',
#  'Begay, Alvin',
#  'Begay, Alvina Y.',
#  'Bel Franquesa, Laura',
#  'Bell, Patrick',
#  'Bell, Samuel',
#  'Bender, Matthew T.',
#  'Benedik, Jean-Philippe',
#  'Berger, John P',
#  'Bernardi, Alexandra E.',
#  'Berrones, Steve',
#  'Bilodeau-Genest, Thomas',
#  'Bin Alias, Mohd Syahidan',
#  'Bishop, Daniel',
#  'Bishop, Nathan',
#  'Biwott, Shadrack',
#  'Blackwell, Ian A',
#  'Blas, Wayne',
#  'Blom, Marcel W',
#  'Blowers, James',
#  'Blunden, Matthew',
#  'Bolanos, Antonio Sr.',
#  'Bolha, Jonathan',
#  'Bonvillain, Frederic X',
#  'Borgen, André',
#  'Boudalia, Said Sr.',
#  'Boulay, Pierre',
#  'Bowen, Caleb',
#  'Bowen, John A.',
#  'Bowie, Nikolas S',
#  'Bowling, Kyle H.',
#  'Bradley, Scott',
#  'Bragg, Isaiah L',
#  'Branick, Connor M',
#  'Bretz, Virgil',
#  'Brewer, Bo',
#  'Brewer, Kenneth',
#  'Brigham, Nathan E',
#  'Broadbent, Logan',
#  'Bromka, Peter',
#  'Brown, Dave R.',
#  'Brown, Dwayne',
#  'Buck, Nathan',
#  'Buckingham, Todd',
#  'Buckner, Mark L.',
#  'Bugbee, Patrick',
#  'Bumbulsky, Jim',
#  'Burgos, Andre C. Sr.',
#  'Burk, Bryan T',
#  'Burke, Tyler J',
#  'Burnett, Clay T.',
#  'Burns, Robert M.',
#  'Burris, Jared',
#  'Butcher, John',
#  'Bybee, Dustin',
#  'Bybee, Ryan R',
#  'Byers, Scott E',
#  'Cabral, Manuel',
#  'Cacciapaglia, Christopher',
#  'Calavan, Brian',
#  'Cale, Eric D.',
#  'Callahan, Patrick M.',
#  'Calzetta, Christopher',
#  'Camara Ortiz, Cesar Sr.',
#  'Campbell, Coby',
#  'Campos Reyes, Jesus A.',
#  'Canan, Mike',
#  'Cancre, Felix L',
#  'Cantini, Adam',
#  'Cao, Yuming',
#  'Capps, Christopher',
#  'Caputo, Mike',
#  'Carbonaro, Jeramie C.',
#  'Carley, Seth A',
#  'Carney, Ryne',
#  'Caron, Patrick',
#  'Carpenter, Joseph K.',
#  'Carreira, Mario P Sr.',
#  'Carroll, Matt J.',
#  'Carron, John B',
#  'Carvajal Riquelme, Pablo',
#  'Casas Herrero, Manuel',
#  'Castano Gonzalez, Angel U. Sr.',
#  'Castillo, Franklin A. Sr.',
#  'Castro, Sebastian',
#  'Castro, Spencer C.',
#  'Cater-Cyker, Zach',
#  'Cawkwell, Philip B',
#  'Chaisson, Stan',
#  'Chang, Ching-Tun',
#  'Chantal, Alain',
#  'Chapman, Stephen P',
#  'Chapruet, Christopher',
#  'Chebet, Wilson',
#  'Chelimo, Rose',
#  'Chen, Cheng Yen',
#  'Cherono, Gladys',
#  'Chesson, Harrell W',
#  'Chiasson, Rejean',
#  'Chichester, Tim',
#  'Childres, Steven L',
#  'Chipsiya, Christopher K.',
#  'Choy, Yan Tsun Jeffrey',
#  'Christie, Robert',
#  'Cibulka, Jeramia',
#  'Cichon, Scott G.',
#  'Cifuentes Fetiva, Miguel Angel Sr.',
#  'Clark, Christopher',
#  'Clark, Sean',
#  'Clements, Aaron',
#  'Cobler, Bill',
#  'Coffee, Kyle',
#  'Collick, Neal',
#  'Colligan, Nora',
#  'Collins, Matt',
#  'Comite, Daniel O.',
#  'Conklin, Eric M',
#  'Consolandi, Paolo Giorgio',
#  'Coogan, Rachel',
#  'Cook, Andrew W.',
#  'Coomer, Colin',
#  'Cooper, Sheldon M',
#  'Corno, Hilary',
#  'Corona Iturriaga, Roberto',
#  'Corona, John L.',
#  'Corso, Jonathan',
#  'Costello, Daniel A.',
#  'Costello, Liz',
#  'Coughlin, Benjamin R.',
#  'Couture, Nathaniel',
#  'Cox, Ryan',
#  'Craigie, Eoin',
#  'Critchfield, Byron L.',
#  'Crossland, Tom',
#  'Cucuzzella, Mark',
#  'Cueto, Rafael',
#  'Cundy, Lance',
#  'Cunha, Will',
#  'Curley, Craig',
#  'Curley, Declan',
#  'Curley, Matt',
#  'Curley, Stephen',
#  'Cusson, Michel',
#  'Cutter, Patrick D',
#  'Cyganik, Jonathan',
#  'Dadabo, Joseph G',
#  'Dallner, Olof S',
#  'Danko, Laszlo',
#  'Davidson, Francois',
#  'Davidson, Terry',
#  'Davis, Rachel',
#  'Davis, Steve T',
#  'Daye, Ryan',
#  'De Samaniego Steta, Fernando',
#  'Deasey, Michael Ryan',
#  'Deba, Buzunesh',
#  'Decamps, William M.',
#  'Deeg, Thomas J',
#  'Dehring, Michael J.',
#  'Delanghe, Sean',
#  'Delia, Ben',
#  'Delong, Candace',
#  'Deshaies, Eric',
#  'Desharnais, Daniel',
#  'Desilets, Jordan H.',
#  'Dever, Shaun R',
#  'Diamond, Anthony',
#  'Dill, Jeff',
#  'Dimbleby, Peter J.',
#  'Dimoff, Carrie',
#  'Dionne, Andrew J',
#  'Dixon, Brian L',
#  'Dixon, David',
#  'Dolney, Daniel',
#  'Donaghy, Roger',
#  'Dorval, Guy',
#  'Doucet, Shelley A',
#  'Dowd, Justin',
#  'Driver, Ian H',
#  'Duhaime, Spencer',
#  'Duhon, Madeline',
#  'Dunlap, Matthew H.',
#  'Duran, Carlos',
#  'Duyn, Jeff H.',
#  'Eastes, Bryan P',
#  'Edora, Felipe T.',
#  'Egge, Mark',
#  'Eles, Stephen A',
#  'Ellenberger, Michael P',
#  'Ellis, Ryan',
#  'Eng, Greg',
#  'England, Stephen',
#  'English, Jordan',
#  'Engtrakul, Chaiwat',
#  'Ernst, Ekkehard',
#  'Fagan, Brian',
#  'Fallas Navarro, Juan R.',
#  'Fallas, Alejandro',
#  'Fan, Alexander',
#  'Farmer, Stuart M.',
#  'Fedden, Lee D',
#  'Feldman, William P.',
#  'Fennon, Myles',
#  'Fernandez, Douglas',
#  'Fernandez, Nestor',
#  'Fernández Jiménez, Luis',
#  'Ferrari, Diego M. Sr.',
#  'Ferreira Filho, Guilherme A.',
#  'Finer, Jonathan K',
#  'Finlay, Gavin',
#  'Fischer, Matthew',
#  'Fisher, James A',
#  'Fisher, Michael D',
#  'Fitzpatrick, Michael J',
#  'Flaherty, Matthew A.',
#  'Flanagan, Lindsey',
#  'Flowerday, Crispin',
#  'Foley, Vivian J.',
#  'Ford, Ryan',
#  'Fortin, Regis',
#  'Fowler, Brian D',
#  'Fraioli, Mario Jr.',
#  'Franken, Christiaan',
#  'Fransen, Bret',
#  'Fraser, Kyle',
#  'Freeman, David J.',
#  'Freudenberger, Holger U. III',
#  'Fukuchi, Yoshinori',
#  'Gabris, Stephen',
#  'Galaviz, Jose F.',
#  'Gallagher, Sean',
#  'Galvin, Mike V',
#  'Gamble, Charlie E',
#  'Garcia, German',
#  'Garcia, Mario A.',
#  'Gardner, Preston',
#  'Garner, Stephen H IV',
#  'Garrison, Scott D',
#  'Garvey, Thomas G IV',
#  'Gates, William E. Jr.',
#  'Gauthier, Jon',
#  'Gavin, Timothy V.',
#  'Geeraert, Jeroen L.',
#  'Gerald, Jean-Philippe',
#  'Gervaix, Francois',
#  'Giammar, David',
#  'Gibbs, Ben',
#  'Gibson, Audrey L.',
#  'Gil Zaragoza, Pablo Sr.',
#  'Gill, Nadine',
#  'Gillette, Jake',
#  'Gilmore, Peter',
#  'Ginnan, Ken',
#  'Girard, Mathieu',
#  'Golaszewski, Michal',
#  'Gollins, Bryan',
#  'Gongora, Enrique Sr.',
#  'Gonzalez, Juan P.',
#  'Gonzalez, Manuel A',
#  'Goodman, John M.',
#  'Gordyan, Ryan',
#  'Goris, Fred P',
#  'Gove, Alberto M.',
#  'Grasela, Michael J',
#  'Grassmeyer, Justin',
#  'Graves, Nicholas',
#  'Gray, Samuel R.',
#  'Graysmark, Charles C',
#  'Greenberg, Robert J.',
#  'Greenham, James D.',
#  'Greenwald, Russell S',
#  'Gress, Shannon',
#  'Grinstead, Tyler J',
#  'Groff, Adam C',
#  'Groner, Roberta',
#  'Grosskopf, Johannes S.',
#  'Groudle, Alan M',
#  'Guldan, Ryan W',
#  'Gundling, Colin',
#  'Gustafsson, Jacob',
#  'Guthals, Nathaniel',
#  'Guzick, William F',
#  'Hackett, Brian',
#  'Hall, Alden W',
#  'Hall, Matt',
#  'Hallman, Stephen J.',
#  'Halusan, Brian M.',
#  'Hambrock, Christian J',
#  'Hamel, Derrick J.',
#  'Hamilton, Tyler',
#  'Hampton, Rob',
#  'Hannah, Rachel',
#  'Hansen, Ryan P',
#  'Hansen, Tyler',
#  'Harder, Tim',
#  'Hardy, Brent J',
#  'Hardy, Sebastien',
#  'Harmon, Christopher',
#  'Hartje, William',
#  'Hartstein, Kevin C',
#  'Harvey, Brian',
#  'Hasay, Jordan',
#  'Haskett, Brian',
#  'Haughton, Daniel',
#  'Heerensperger, Mark E',
#  'Hein, Christine L.',
#  'Herrick, Danna',
#  'Herzet, Dominique',
#  'Hesselbjerg, Anders R.',
#  'Heun, Aaron J',
#  'Hicks, Stuart',
#  'Highlander, Andy',
#  'Hillyard, Matthew',
#  'Hilty, Jonathan B.',
#  'Hobbs, Steve',
#  'Hoedl, Hanspeter',
#  'Hoerger, Jacob',
#  'Hoffman, Michael',
#  'Hola, Tim',
#  'Holder, David',
#  'Holtz, Zachary',
#  'Hoogkamer, Wouter',
#  'Hoover, Aaron',
#  'Hotchandani, Timothy',
#  'Hotek, Kiefer K',
#  'Howard, Doug',
#  'Howard, Jason F',
#  'Howell, Jason A',
#  'Howell, Kristian',
#  'Huang, Kuo-Lun',
#  'Huberty, Bryan',
#  'Hudson, Jay D',
#  'Humphrey, Luke',
#  'Hunter, Colin C',
#  'Hunter, Dale',
#  'Hunter, Iain',
#  'Hunziker, Eric',
#  'Hurlbutt, Gretchen G',
#  'Husak, Tyler',
#  'Hutson, Greg',
#  'Huwe, Kevin',
#  'Hyland, Sean P.',
#  'Iacovone, Dustin',
#  'Ilfrey, Campbell',
#  'Impellitteri, Sal',
#  'Inniger, Nicholas P',
#  'Inoue, Daichi',
#  'Inoue, Yusuke',
#  'Irwin, Cory',
#  'Ito, Atsushi',
#  'Iwasa, Kaito',
#  'Jackson, Christopher',
#  'Jackson, James P',
#  'Jackson, Veronica M',
#  'Jahn, Corbyn N.',
#  'Jansen-Van Rensburg, Mauritz C.',
#  'Jarvis, Collin',
#  'Jensen, Rune B.',
#  'Jizmagian, Greg S',
#  'Johnson, Charlie',
#  'Johnson, Harley T',
#  'Johnson, Jim',
#  'Johnston, Christoffer',
#  'Jones, Craig',
#  'Jones, Logan M.',
#  'Jones, Mark T',
#  'Jones, Matthew',
#  'Jongh, Robert',
#  'Jordan, Zack',
#  'Jungkans, Chris W.',
#  'Jurkovich, Evan',
#  'Kaehr, Andrew T.',
#  'Kai, Hiroki',
#  'Kam, Max',
#  'Karakoyunlu, Deniz',
#  'Kardous, Pascal',
#  'Kardous, Pierre',
#  'Kariolis, Vasilis S',
#  'Kartanowicz, Paul M.',
#  'Kawata, Ryohei',
#  'Kearney, Sean',
#  'Keathley, Franklin',
#  'Keena, Joshua M.',
#  'Keflezighi, Meb',
#  'Keller, Andrew C',
#  'Kelley, Daniel',
#  'Kellner, John R',
#  'Kennedy, Morgan',
#  'Kenny, Ryan F',
#  'Keno, Brian',
#  'Keshian, Gregory',
#  'Kilbourne, Michael',
#  'Kimura, Jonathan M',
#  'King, David R.',
#  'King, Travis E.',
#  'Kingston, Hudson',
#  'Kinley, Jordan',
#  'Kipketer, Valentine',
#  'Kiplagat, Edna',
#  'Kiracofe, Drew P',
#  'Kirk, Jacob D',
#  'Kisri, Rachid',
#  'Kivett, Lewis',
#  'Klastava, Nicholas',
#  'Klecker, Jack R',
#  'Klein, Patrick J',
#  'Kloehn, Ian',
#  'Klosterhoff, Brett S',
#  'Klucznik, Christopher',
#  'Knight, Steven J.',
#  'Kochanek, Krystian',
#  'Kolet, Thijs',
#  'Koranda, Jeff',
#  'Korir, Wesley',
#  'Kortman, John',
#  'Kosgei, Brigid',
#  'Kosters, Eric S',
#  'Kotter, Jonathan B.',
#  'Kovalchick, Christopher',
#  'Krall, David',
#  'Kramer, Robert',
#  'Krebs, Justin',
#  'Kress, Stephen',
#  'Krieche, Issam',
#  'Krieg, Sam D',
#  'Kropelnicki, Jesse',
#  'Krusell, Brian',
#  'Kuchwara, Sam N.',
#  'Kuehler, Jon',
#  'Kuhlenschmidt, Bernd',
#  'Kurosawa, Kana',
#  'Kurtz, Jordan H',
#  'Kwon, Daniel',
#  'Kyereme, Kojo',
#  'Lagoutte, Julien',
#  'Lair, Jessie E',
#  'Landau, Kate',
#  'Landeo Carranza, Oliver Sr.',
#  'Landry, Paul',
#  'Langerak, Bruce',
#  'Lanning, Jerry A',
#  'Lapp, Samuel M',
#  'Larosa, John',
#  'Larosa, Mark',
#  'Laskowski, Conrad J',
#  'Lautzenheiser, Daniel',
#  'Law, Jacob B',
#  'Lawyer, Nicholas K',
#  'Lazo, Reynaldo',
#  'Le Roy, Tyler W',
#  'Leblanc, Daniel',
#  'Legg, Hayden B',
#  'Legh, Christopher P.',
#  'Leishman, Eric S',
#  'Lemelman, Daniel',
#  'Leon, Alex',
#  'Leonard, Dan',
#  'Leonard, Matthew',
#  'Leone, Simo',
#  'Lesser, Dan',
#  'Lhuissier, Francois',
#  'Li, Yipeng',
#  'Lima, Alexsandro S. Sr.',
#  'Lin, Mason',
#  'Linden, Desiree',
#  'Lindenauer, Jon',
#  'Lindsey, Thomas',
#  'List, Jay',
#  'Lizotte, Megan L.',
#  'Lloyd, James',
#  'Loeffler, Eric',
#  'Lohr, Alexander R.',
#  'Lok, Ryan',
#  'Lonergan, Eric',
#  'Longo, John',
#  'Looi, Alexander',
#  'Lopez Borboy, Alfredo',
#  'Lopez, Raul M. Jr.',
#  'Loveland, Eric C',
#  'Lovig, Christy L.',
#  'Luc, Ryan',
#  'Lucas, Nigel',
#  'Lucier, Jeremy',
#  'Lütgenau, Peter',
#  'Mac-Thiong, Jean-Marc',
#  'Macdonald, Adrian S.',
#  'Madej, Robert',
#  'Madrigal, Benjamin',
#  'Mahoney, Kevin J',
#  'Maiyo, Augustus K.',
#  'Malek, Paul V',
#  'Manning, Aaron',
#  'Maravilla, Jorge',
#  'Marilly, Mathieu',
#  'Martin, Neil E',
#  'Martinez Balbuena, Emilio',
#  'Martinez Solano, Juan Manuel Jr.',
#  'Martins, Cesar A.',
#  'Marx, Christian',
#  'Mason, Jonathan R',
#  'Mathews, Brandon T',
#  'Matthews, Martin',
#  'Matuszak, Paul M.',
#  'McArthur, Scott D.',
#  'McColl, Noah',
#  'McGettigan, Joshua D.',
#  'McHaffie, Jake',
#  'McMahan, Dot',
#  'McNamara, Brian',
#  'McSween, Matt K.',
#  'McWalters, Teresa',
#  'Mcafee, Jack',
#  'Mccann, Greg',
#  'Mccarty, Van IV',
#  'Mccauley, Sean',
#  'Mcclung, Joshua',
#  'Mccormick, Marty',
#  'Mccue, Daniel T',
#  'Mcdonough, Bobby',
#  'Mcevoy, Andrew R',
#  'Mcevoy, James R',
#  'Mckay, David',
#  'Mckeel, Scott R',
#  'Mckinley, Ian D',
#  'Mckinley, Kyle W',
#  'Mclaughlin, Donald W',
#  'Mclaughlin, Pat',
#  'Mcmillan, Erik D',
#  'Mcquade, Colin',
#  'Medd, Steven',
#  'Medeiros, J Matthew',
#  'Meier, Fabian',
#  'Meigs, Tim',
#  'Mejia Huerta, Bernardo B.',
#  'Melendez, Carlos Manuel M. Sr.',
#  'Mena Solorzano, Diego Sr.',
#  'Mendoza, Eric',
#  'Mercier, Christian',
#  'Merkt, Juerg',
#  'Metivier, Ryan A',
#  'Metzger, David W',
#  'Michalski, Steven L',
#  'Michell, Robert G',
#  'Middleton, Ryan',
#  'Miklic, Mirko Bogomir',
#  'Miller, Christopher A',
#  'Miller, James L',
#  'Mindel, Scott',
#  'Mininger, Norman H',
#  'Mitchell, Dustin T',
#  'Mitsumori, Satoshi',
#  'Montoya, Alvaro Sr.',
#  'Moore, Jim',
#  'Moraine, Olivier',
#  'Moreau, Louis',
#  'Moreira, Alexandre H.',
#  'Morgan, Kevin',
#  'Morgan, Mike',
#  'Morlan, Bruno',
#  'Morris, Jonathan',
#  'Morrison, Michael S',
#  'Motta, Ronaldo V. Sr.',
#  'Moyer, Dave',
#  'Mullen, Jay',
#  'Mullikin, Ian',
#  'Munoz Garcia, Javier',
#  'Murphy, Timothy A.',
#  'Murray, Patrick',
#  'Muskopf, Christopher J.',
#  'Mutai, Emmanuel',
#  'Mylonas, Dimitrios',
#  'Naro, Brandyn',
#  'Ndhlovu, Pardon',
#  'Neill, Ian',
#  'Nesbitt, Drew T',
#  'Nevalainen, Alec',
#  'Newhouse, James B',
#  'Nieto, Ben',
#  'Nishimura, Akira',
#  'Nolan, Alison L',
#  'Norcross, Robert A III',
#  'Nukuri, Diane',
#  'Nurse, Ian',
#  'Nyasango, Cutbert',
#  "O'Callaghan, Paul S.",
#  "O'Donoghue, Graham",
#  "O'Leary, Paddy C",
#  "O'Neale, Dion",
#  "O'Sullivan, James",
#  'O, Loc M',
#  'Ocampo, Rodolfo R.',
#  'Ochoa, Raul E',
#  'Ohara, Chip',
#  'Ohashi, Shinya',
#  'Oliveira, Bruno L. Sr.',
#  'Oliver, Matthew',
#  'Ollinger, Patrick',
#  'Onigkeit, James',
#  'Orellana, Steve',
#  'Orifice, Michael',
#  'Orlando, Matthew P',
#  'Ornelas, Zachary',
#  'Osako, Suguru  ',
#  'Oswald, Sean-Patrick R.',
#  'Outlaw, Robert A.',
#  'Ovsyannikov, Sergey',
#  'Ozahowski, Matt',
#  'Pace, Joseph',
#  'Palma, Louis J.',
#  'Pardo, Federico',
#  'Park, Jim',
#  'Parker, Hugh F',
#  'Parrott, John',
#  'Parton, Nicholas',
#  'Pauker, Semjon',
#  'Paullin, Matthew J.',
#  'Payne, Brandon L',
#  'Pearson, Benjamin L',
#  'Pearson, Blake',
#  'Pearson, Gregory',
#  'Pearson, Neil F.',
#  'Penny, J A',
#  'Perez, Abel Sr.',
#  'Perez, Christian',
#  'Perez, James P.',
#  'Perkins, Jerome',
#  'Perry, Alexander R',
#  'Perry, Tim',
#  'Peterson, Alex A.',
#  'Peterson, Michael T',
#  'Pfander, C Adam',
#  'Philbrook, Lauren',
#  'Phillips, Caitlin',
#  'Phillips, Michael T',
#  'Pierce, Clayton J.',
#  'Pierce, Keith',
#  'Piirimae, Partel',
#  'Pineda Morales, Guillermo Sr.',
#  'Piper, Paul J',
#  'Pires, Corey',
#  'Pita, Javier',
#  'Place, Ryan J',
#  'Plennevaux, Eric',
#  'Pommier, Jean',
#  'Post, Jann',
#  'Postaski, Michael L',
#  'Power, Rich M',
#  'Prechtel, Jonathan H.',
#  'Premkumar, Ashish',
#  'Preslar, Matt L',
#  'Prussing, Pablo Alejandro',
#  'Puleo, Mark',
#  'Puskedra, Luke',
#  'Puth, Daniel',
#  'Puzey, Jacob',
#  'Puzey, Thomas R.',
#  'Qi, Shun',
#  'Qin, Zhenning',
#  'Quesnell, Michael',
#  'Quigley, Sean',
#  'Quinn, Julianne',
#  'Quinteros, Martin',
#  'Rabasco, Mark T.',
#  'Rabe, Michael',
#  'Rafael Calderon, Victor M.',
#  'Rama Gómez, Iván Sr.',
#  'Ramirez, Ernesto A',
#  'Ramirez, Felipe',
#  'Rangel, Elenilton V.',
#  'Rankin, Greg',
#  'Rasmussen, Erik C',
#  'Ratliff, Alex J',
#  'Ray, Joseph',
#  'Rayner, Kenny',
#  'Rea, Ian',
#  'Reaves, Patrick',
#  'Reed, Erik',
#  'Reed, Sam J.',
#  'Regan, John P.',
#  'Rego, Christopher',
#  'Reichard, Henry E',
#  'Reilly, Jason T.',
#  'Reisenauer, Matthew',
#  'Remillard, Charles A.',
#  'Retzlaff, Chris',
#  'Revenis, Bradley D',
#  'Reynolds, Bryn P.',
#  'Ricardi, Joshua',
#  'Richardson, Chris',
#  'Richnavsky, Scott',
#  'Richter, Peter W Sr.',
#  'Rieger, Cameron',
#  'Rininger, Bradley T',
#  'Ripple, Nolan',
#  'Ritchie, Tom C Jr.',
#  'Rivas, Jorge A',
#  'Rivera, Will',
#  'Roach, Adam D',
#  'Roach, Andrew',
#  'Roberts, Duncan',
#  'Robertson, Stuart',
#  'Robinson, Knox',
#  'Robles, Norberto',
#  'Roche, Nicholas N.',
#  'Roels, Guillaume',
#  'Rogers, Taylor W',
#  'Rolfes, Greg',
#  'Root, Thomas',
#  'Rose, Jordan',
#  'Rosenberg-Wohl, Jacob',
#  'Rosinski, Steve',
#  'Ross, Jerome',
#  'Rossi, Timothy M.',
#  'Roulier, Sebastien',
#  'Rouse, Matthew',
#  'Royer, Dominic',
#  'Royston, J. P. II',
#  'Rui, Ning',
#  'Ruiz Rodriguez, Carlos',
#  'Rupp, Galen   ',
#  'Rutt, Matthew',
#  'Rutter, Martin J.',
#  'Ryan, Elizabeth',
#  'Ryan, Jamaal',
#  'Sadler, Jeff',
#  'Sajulga, Felipe Iii L.',
#  'Samarin, Alex',
#  'Samland, Marc C',
#  'Sanabria, Leonardo E.',
#  'Sanchez, Sam R',
#  'Sanderson, Samuel',
#  'Sandoval, Mauricio Sr.',
#  'Sandreuter, Stefan B.',
#  'Santiago, Andre',
#  'Santos, Juan A',
#  'Sarkovics, Rodney',
#  'Satterfield, Joseph W.',
#  'Saulnier, Emmett',
#  'Savard-Gagnon, David',
#  'Savaria, Mathieu',
#  'Saviano, Louis L. III',
#  'Scanlan, Jeremy C',
#  'Schiele, Austin',
#  'Schiemann, Chris J',
#  'Schmidt, Walter T.',
#  'Schmitt, Craig P',
#  'Schmitz, Jake',
#  'Schneider, Martin',
#  'Schramm, Cedric',
#  'Schrandt, Erik J',
#  'Schuler, Eric',
#  'Schwartzbard, Aaron',
#  'Scott, Reed C.',
#  'Scoville, Morgan B.',
#  'Scudder, John L',
#  'Sefir, Dino',
#  'Seifert, Matthew',
#  'Selters, Clark',
#  'Serafini, Louis',
#  'Shaw, Michael P.',
#  'She, Chunfeng',
#  'Sheaff, Spencer T',
#  'Sherf, Aaron',
#  'Shields, Andrew J.',
#  'Shields, Brian',
#  'Shimoda, Ryuzo',
#  'Shingleton, Jeremy',
#  'Shirley, Brent',
#  'Shold, Kristopher',
#  'Silva, Ryan J.',
#  'Siqueiros, Carlos A',
#  'Sitarz, Hans',
#  'Skurka, Andrew',
#  'Skurski, Joseph',
#  'Sloan, Ryan S',
#  'Smart, Larry',
#  'Smith, Adam D',
#  'Smith, Christopher M.',
#  'Smith, David R',
#  'Smith, David W. Jr.',
#  'Smith, Kevin J.',
#  'Smith, Shane P.',
#  'Smith, Timothy D',
#  'Smith, Todd J',
#  'Smith, Zachery',
#  'Snow, Nick J',
#  'Sorenson, Erik J',
#  'Sosinski, Jimmy S',
#  'Spangler, Allan R',
#  'Spellman, John W IV',
#  'Sprague, Dustin L',
#  'Sprieser, Steven',
#  'Stadolnik, Michael',
#  'Stange, Michael',
#  'Stapenhorst, Guilherme',
#  'Starbuck, Ryan',
#  'Steidl, Uli',
#  'Stenger, Eddie',
#  'Stephens, Jake',
#  'Stephenson, Jay P.',
#  'Stevens, Ashley',
#  'Stewart, Ben',
#  'Stewart, Simon',
#  'Stone, Chris C.',
#  'Strandby, Brian B.',
#  'Strasburg, Andrew W',
#  'Stucky, Raquel',
#  'Sullivan, Harrison',
#  'Susmann, Austin',
#  'Swanson, Erik',
#  'Swanson, William G',
#  'Sweeney, Derrik W.',
#  'Swenson, Will',
#  'Syed, Aaqib',
#  'Synan, Nicholas',
#  'Synofzik, Matthis',
#  'Szymoniak, Blazej',
#  'Takano, Walter Sr.',
#  'Takaoka, Masahiro',
#  'Talhelm, Alan F.',
#  'Tarbell, Kody M.',
#  'Tarm, Toomas',
#  'Tateishi, Caitlyn Claire',
#  'Taylor, Alexander J.',
#  'Teigen, Sam D',
#  'Temple, Brian',
#  'Tenforde, Adam S',
#  'Theard, Jean-Baptiste',
#  'Thielman, Michael J',
#  'Thiriet, Olivier',
#  'Thirumurthy, Harsha',
#  'Thomas, Jason',
#  'Thomas, Malcolm',
#  'Thompson, Christian C.',
#  'Thor, Matthew',
#  'Thorson, Cleve M',
#  'Tian, Jun',
#  'Tissue, Jeffrey R',
#  'Togami, Katsuhiro',
#  'Tomaszewski, Jeffrey',
#  'Tongue, Patrick K.',
#  'Tooley, Michael',
#  'Totman, Andrew',
#  'Trammell, Chadwick D.',
#  'Trampe, Travis',
#  'Trimaille, Johan',
#  'Tropf, Jordan',
#  'Trudel, Samuel',
#  'Truesdell, Carson W',
#  'Tsai, Chih-Yuan',
#  'Tsegay, Yemane',
#  'Tucker, Aaron',
#  'Turner, Wesley C',
#  'Tydlaska, Shawn',
#  'Uchiki, Tomoaki',
#  'Urbanski, Matthew',
#  'Vajente, Gabriele',
#  'Valcke, Tomas L.',
#  'Valentine, Eddie',
#  'Valentine, Zach',
#  'Valicka, Christopher G',
#  'Van Meter, Kathryn M.',
#  'Vanderven, Ian',
#  'Vanderwoude, Darryl E.',
#  'Vangampleare, Stephen',
#  'Vanos, William',
#  'Varela, Jonnathan',
#  'Vargas, Will',
#  'Varner, Alexander',
#  'Veldhuis, Jeroen',
#  'Versen, William R',
#  'Vesbach, Steve',
#  'Vest, Jamie',
#  'Viavattine, Joe R.',
#  'Vizcarra, Carlos H',
#  'Waite, Steven T.',
#  'Wallace, Jack',
#  'Wallace, Jeremy',
#  'Waller, Edward',
#  'Walsh, Sorrell',
#  'Waltz, Seth R',
#  'Wang, Baoyan',
#  'Wang, Xiao',
#  'Ward, Jared',
#  'Wardian, Michael R.',
#  'Waxman, Marc',
#  'Weeks, Paul',
#  'Wegener, Joel D',
#  'Wells, Clint',
#  'Wendel, Nicholas',
#  'Whitcraft, Joshua D.',
#  'White, Erick',
#  'White, Laurent',
#  'Whitlow, Dustin M',
#  'Whitty, Fergal M.',
#  'Wiberley, Kelsey L.',
#  'Widlowski, Daniel',
#  'Widtfeldt, Daniel',
#  'Wiegand, Robert H Jr.',
#  'Wieker, Luke M',
#  'Wiersum, Matthew J',
#  'Wijeyeratne, Shihan',
#  'Wilhelm, Christophe G.',
#  'Williamson, David',
#  'Williamson, Jerry A',
#  'Wilson, Douglas A',
