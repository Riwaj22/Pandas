# %%
import pandas as pd
import numpy as np

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
# Randomly select 10 food items and assign the resulting dataframe to a new variable called nutr_mini

# %%
nutr_mini = nutrition.sample(n=10)

# %%
nutr_mini
# Out:
#                                                    serving_size  calories  \
# name
# Chicken, raw, separable fat, broilers or fryers           100 g       629
# Fish, without skin and bones, drained solids, c...        100 g       136
# Pork, raw, separable fat, fresh                           100 g       632
# Chicken, raw, meat only, wing, broilers or fryers         100 g       126
# Alcoholic beverage, Semillon, white, table, wine          100 g        82
# Restaurant, without meat, vegetable lo mein, Ch...        100 g       121
# KEEBLER, Fudge Sticks, FUDGE SHOPPE                       100 g       529
# Pork, braised, cooked, tongue, variety meats an...        100 g       271
# Soup, prepared with equal volume water, canned,...        100 g        28
# Beans, without salt, drained, boiled, cooked, s...        100 g        22
#
#                                                    total_fat saturated_fat  \
# name
# ...

# %%
# From nutr_mini extract the total fat and cholestrol columns for all rows

# %%
nutr_mini.loc[:,['total_fat','cholesterol']]
# Out:
#                                                    total_fat cholesterol
# name
# Chicken, raw, separable fat, broilers or fryers          68g        58mg
# Fish, without skin and bones, drained solids, c...      4.2g        83mg
# Pork, raw, separable fat, fresh                          66g        72mg
# Chicken, raw, meat only, wing, broilers or fryers       3.5g        57mg
# Alcoholic beverage, Semillon, white, table, wine          0g           0
# Restaurant, without meat, vegetable lo mein, Ch...      2.4g           0
# KEEBLER, Fudge Sticks, FUDGE SHOPPE                      27g           0
# Pork, braised, cooked, tongue, variety meats an...       19g       146mg
# Soup, prepared with equal volume water, canned,...      0.8g         2mg
# Beans, without salt, drained, boiled, cooked, s...      0.3g           0

# %%
# Extract all the columns from vitamin_b12 to the end, for the first,second and third rows

# %%
nutr_mini.iloc[[1,2,3],[20,-1]]
# Out:
#                                                    vitamin_b12    water
# name
# Fish, without skin and bones, drained solids, c...    4.96 mcg  70.63 g
# Pork, raw, separable fat, fresh                       0.67 mcg  24.76 g
# Chicken, raw, meat only, wing, broilers or fryers     0.38 mcg  74.95 g

# %%
nutr_mini.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Chicken, raw, separable fat, broilers or fryers to Beans, without salt, drained, boiled, cooked, sprouted, mature seeds, pinto
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   serving_size                 10 non-null     object
#  1   calories                     10 non-null     int64
#  2   total_fat                    10 non-null     object
#  3   saturated_fat                8 non-null      object
#  4   cholesterol                  10 non-null     object
#  5   sodium                       10 non-null     object
#  6   choline                      10 non-null     object
#  7   folate                       10 non-null     object
#  8   folic_acid                   10 non-null     object
#  9   niacin                       10 non-null     object
#  10  pantothenic_acid             10 non-null     object
# ...

# %%
nutr_mini.head(3)
# Out:
#                                                    serving_size  calories  \
# name
# Chicken, raw, separable fat, broilers or fryers           100 g       629
# Fish, without skin and bones, drained solids, c...        100 g       136
# Pork, raw, separable fat, fresh                           100 g       632
#
#                                                    total_fat saturated_fat  \
# name
# Chicken, raw, separable fat, broilers or fryers          68g           20g
# Fish, without skin and bones, drained solids, c...      4.2g          0.7g
# Pork, raw, separable fat, fresh                          66g           22g
#
#                                                    cholesterol     sodium  \
# name
# Chicken, raw, separable fat, broilers or fryers           58mg   32.00 mg
# Fish, without skin and bones, drained solids, c...        83mg  378.00 mg
# Pork, raw, separable fat, fresh                           72mg   47.00 mg
#
# ...

# %%
nutr_mini.at['Pork, raw, separable fat, fresh','calories']
# Out:
# 632
