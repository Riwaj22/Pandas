# %%
import pandas as pd
import numpy as np

# %%
# Reading data

nutrition = pd.read_csv(r"C:\Users\97798\Desktop\Pandas\data frames\nutrition.csv",index_col="Unnamed: 0")

# %%
# Reading data

nutrition = pd.read_csv(r"C:\Users\97798\Desktop\Pandas\data frames\nutrition.csv",index_col="name")

# %%
nutrition.head(5)
# Out:
#                  Unnamed: 0 serving_size  calories total_fat saturated_fat  \
# name
# Cornstarch                0        100 g       381      0.1g           NaN
# Nuts, pecans              1        100 g       691       72g          6.2g
# Eggplant, raw             2        100 g        25      0.2g           NaN
# Teff, uncooked            3        100 g       367      2.4g          0.4g
# Sherbet, orange           4        100 g       144        2g          1.2g
#
#                 cholesterol    sodium  choline     folate folic_acid  ...  \
# name                                                                  ...
# Cornstarch                0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...
# Nuts, pecans              0   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...
# Eggplant, raw             0   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...
# Teff, uncooked            0  12.00 mg  13.1 mg          0          0  ...
# ...

# %%
nutrition.total_fat.head()
# Out:
# name
# Cornstarch         0.1g
# Nuts, pecans        72g
# Eggplant, raw      0.2g
# Teff, uncooked     2.4g
# Sherbet, orange      2g
# Name: total_fat, dtype: object

# %%
nutrition.total_fat.sum()
# Out:
# '0.1g72g0.2g2.4g2g0.3g0.7g23g24g18g0g0.4g0.1g7.2g15g4.5g16g0.4g0.9g9.2g0.5g1.7g5.9g33g15g0g0g3g0.4g68g1.5g0.2g11g0.8g16g0.2g0.5g50g0.3g0.6g3g16g3.1g11g2.4g0g0.3g0.5g99g0.1g5.3g5.3g0.4g5.3g0.2g0.3g6.4g22g1g14g10g17g14g4.3g22g36g0.7g100g27g2.8g5.8g14g0.7g1.5g11g34g0.2g0.9g4.6g0g0.4g19g0.2g10g28g6.7g6.7g0.3g0.3g44g37g14g50g0.9g0.7g0.1g0.7g8g10g19g9.2g0g0.2g8.6g1.3g14g0.4g0.2g8.2g5.2g3.3g2.1g0.1g80g0.5g1.4g0.4g3.3g0.2g0.7g0.1g9.4g0.3g0.6g29g0.2g1.4g0.2g0.4g1.2g1.8g0g0.9g0.2g1.4g0.8g1.5g9.8g0g13g16g19g7.4g0.2g5.2g29g0.3g9.9g22g14g15g4.1g0.5g3.5g15g20g32g1g81g0.2g1.6g0g17g22g7.1g7.4g0.2g8.7g1.4g34g0.3g6.3g30g8.1g0.2g0.1g3.7g0.6g0.3g3.9g0.3g1.2g29g14g26g1.1g2g13g0g9g22g3.7g100g0.1g2.1g2.1g0.3g0.2g6.8g8.1g8.3g2.4g0.2g23g6.7g1g0.3g0.2g0.1g12g17g0.1g100g3.4g0.2g6.7g1.5g22g0g1g25g34g3.6g100g7.3g9g1.6g0.4g0.3g18g0.4g9.5g1.4g11g3.1g1.5g0g2.4g3.6g0g15g1.2g6.6g0.7g4.2g15g0.1g0.5g0.2g0.1g3.5g3g0.1g0.4g0.1g0.3g100g31g2.8g9.7g2.3g11g1.7g0.1g1.7g0.5g4.7g0.5g0.2g8.6g18g25g0.5g0.5g26g7.7g0.1g0.1g100g1.1g
# ...

# %%
nutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8789 entries, Cornstarch to Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   8789 non-null   int64
#  1   serving_size                 8789 non-null   object
#  2   calories                     8789 non-null   int64
#  3   total_fat                    8789 non-null   object
#  4   saturated_fat                7199 non-null   object
#  5   cholesterol                  8789 non-null   object
#  6   sodium                       8789 non-null   object
#  7   choline                      8789 non-null   object
#  8   folate                       8789 non-null   object
#  9   folic_acid                   8789 non-null   object
#  10  niacin                       8789 non-null   object
# ...

# %%
nutrition.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8789 entries, Cornstarch to Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round
# Columns: 76 entries, Unnamed: 0 to water
# dtypes: int64(3), object(73)
# memory usage: 5.2+ MB

# %%
# .astype method

# %%
df = pd.DataFrame({
    
    'age':[12,12,15,47],
    'weight':[22.2,55.6,78.9,88.88],
    'height':[1.72,1.74,1.91,1.54]


})

# %%
df
# Out:
#    age  weight  height
# 0   12   22.20    1.72
# 1   12   55.60    1.74
# 2   15   78.90    1.91
# 3   47   88.88    1.54

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     4 non-null      int64
#  1   weight  4 non-null      float64
#  2   height  4 non-null      float64
# dtypes: float64(2), int64(1)
# memory usage: 224.0 bytes

# %%
df = df.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     4 non-null      float64
#  1   weight  4 non-null      float64
#  2   height  4 non-null      float64
# dtypes: float64(3)
# memory usage: 224.0 bytes

# %%
df.astype({'age':int})
# Out:
#    age  weight  height
# 0   12   22.20    1.72
# 1   12   55.60    1.74
# 2   15   78.90    1.91
# 3   47   88.88    1.54

# %%
nutrition.iloc[:4,:].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 nutrition.iloc[:4,:].astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
dfm = nutrition.iloc[:6,:2]

# %%
dfm.replace(to_replace='100 g',value=100).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, Cornstarch to Cauliflower, raw
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    6 non-null      int64
#  1   serving_size  6 non-null      int64
# dtypes: int64(2)
# memory usage: 144.0+ bytes

# %%
dfm.replace('g','')
# Out:
#                   Unnamed: 0 serving_size
# name
# Cornstarch                 0        100 g
# Nuts, pecans               1        100 g
# Eggplant, raw              2        100 g
# Teff, uncooked             3        100 g
# Sherbet, orange            4        100 g
# Cauliflower, raw           5        100 g

# %%
dfm.replace('\sg','',regex=True).astype(int)
# Out:
#                   Unnamed: 0  serving_size
# name
# Cornstarch                 0           100
# Nuts, pecans               1           100
# Eggplant, raw              2           100
# Teff, uncooked             3           100
# Sherbet, orange            4           100
# Cauliflower, raw           5           100

# %%
dfm.head()
# Out:
#                  Unnamed: 0 serving_size
# name
# Cornstarch                0        100 g
# Nuts, pecans              1        100 g
# Eggplant, raw             2        100 g
# Teff, uncooked            3        100 g
# Sherbet, orange           4        100 g

# %%
type(dfm)
# Out:
# pandas.core.frame.DataFrame

# %%
nutrition.head(10)
# Out:
#                     Unnamed: 0 serving_size  calories total_fat saturated_fat  \
# name
# Cornstarch                   0        100 g       381      0.1g           NaN
# Nuts, pecans                 1        100 g       691       72g          6.2g
# Eggplant, raw                2        100 g        25      0.2g           NaN
# Teff, uncooked               3        100 g       367      2.4g          0.4g
# Sherbet, orange              4        100 g       144        2g          1.2g
# Cauliflower, raw             5        100 g        25      0.3g          0.1g
# Taro leaves, raw             6        100 g        42      0.7g          0.2g
# Lamb, raw, ground            7        100 g       282       23g           10g
# Cheese, camembert            8        100 g       300       24g           15g
# Vegetarian fillets           9        100 g       290       18g          2.8g
#
#                    cholesterol     sodium  choline      folate folic_acid  \
# name
# ...

# %%
# more patterns

# %%
# collecting the units

# %%
nutrition.replace('','',regex=True)
# Out:
#                                                     Unnamed: 0 serving_size  \
# name
# Cornstarch                                                   0        100 g
# Nuts, pecans                                                 1        100 g
# Eggplant, raw                                                2        100 g
# Teff, uncooked                                               3        100 g
# Sherbet, orange                                              4        100 g
# ...                                                        ...          ...
# Beef, raw, all grades, trimmed to 0" fat, separ...        8784        100 g
# Lamb, cooked, separable lean only, composite of...        8785        100 g
# Lamb, raw, separable lean and fat, composite of...        8786        100 g
# Beef, raw, all grades, trimmed to 0" fat, separ...        8787        100 g
# Beef, raw, all grades, trimmed to 0" fat, separ...        8788        100 g
#
# ...

# %%
nutrition.sample(20,axis=1).head()
# Out:
#                  protein galactose caffeine    niacin glutamic_acid  \
# name
# Cornstarch        0.26 g         0  0.00 mg  0.000 mg       0.053 g
# Nuts, pecans      9.17 g         0  0.00 mg  1.167 mg       1.829 g
# Eggplant, raw     0.98 g         0  0.00 mg  0.649 mg       0.186 g
# Teff, uncooked   13.30 g    0.00 g        0  3.363 mg       3.349 g
# Sherbet, orange   1.10 g         0  0.00 mg  0.063 mg             0
#
#                 hydroxyproline sucrose riboflavin selenium  \
# name
# Cornstarch                   0       0   0.000 mg  2.8 mcg
# Nuts, pecans                 0  3.90 g   0.130 mg  3.8 mcg
# Eggplant, raw                0  0.26 g   0.037 mg  0.3 mcg
# Teff, uncooked               0  0.62 g   0.270 mg  4.4 mcg
# Sherbet, orange              0       0   0.097 mg  1.5 mcg
#
#                 saturated_fatty_acids arginine lutein_zeaxanthin  proline  \
# name
# Cornstarch                    0.009 g  0.012 g          0.00 mcg  0.024 g
# ...

# %%
nutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8789 entries, Cornstarch to Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   8789 non-null   int64
#  1   serving_size                 8789 non-null   object
#  2   calories                     8789 non-null   int64
#  3   total_fat                    8789 non-null   object
#  4   saturated_fat                7199 non-null   object
#  5   cholesterol                  8789 non-null   object
#  6   sodium                       8789 non-null   object
#  7   choline                      8789 non-null   object
#  8   folate                       8789 non-null   object
#  9   folic_acid                   8789 non-null   object
#  10  niacin                       8789 non-null   object
# ...

# %%
units = nutrition.astype(str).replace('[^a-zA-Z]','',regex=True)

# %%
units.head()
# Out:
#                 Unnamed: 0 serving_size calories total_fat saturated_fat  \
# name
# Cornstarch                            g                  g           nan
# Nuts, pecans                          g                  g             g
# Eggplant, raw                         g                  g           nan
# Teff, uncooked                        g                  g             g
# Sherbet, orange                       g                  g             g
#
#                 cholesterol sodium choline folate folic_acid  ... fat  \
# name                                                          ...
# Cornstarch                      mg      mg    mcg        mcg  ...   g
# Nuts, pecans                    mg      mg    mcg        mcg  ...   g
# Eggplant, raw                   mg      mg    mcg        mcg  ...   g
# Teff, uncooked                  mg      mg                    ...   g
# Sherbet, orange          mg     mg      mg    mcg        mcg  ...   g
#
# ...

# %%
units.saturated_fat.value_counts()
# Out:
# g      7199
# nan    1590
# Name: saturated_fat, dtype: int64

# %%
units['saturated_fat'].value_counts()
# Out:
# g      7199
# nan    1590
# Name: saturated_fat, dtype: int64

# %%
units['saturated_fat'].mode()
# Out:
# 0    g
# Name: saturated_fat, dtype: object

# %%
units.mode()
# Out:
#   Unnamed: 0 serving_size calories total_fat saturated_fat cholesterol sodium  \
# 0                       g                  g             g          mg     mg
#
#   choline folate folic_acid  ... fat saturated_fatty_acids  \
# 0      mg    mcg        mcg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine water
# 0                      mg       g   g       mg          mg     g
#
# [1 rows x 76 columns]

# %%
units = units.mode()

# %%
units
# Out:
#   Unnamed: 0 serving_size calories total_fat saturated_fat cholesterol sodium  \
# 0                       g                  g             g          mg     mg
#
#   choline folate folic_acid  ... fat saturated_fatty_acids  \
# 0      mg    mcg        mcg  ...   g                     g
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                           g                           g
#
#   fatty_acids_total_trans alcohol ash caffeine theobromine water
# 0                      mg       g   g       mg          mg     g
#
# [1 rows x 76 columns]

# %%
nutrition.head()
# Out:
#                  Unnamed: 0 serving_size  calories total_fat saturated_fat  \
# name
# Cornstarch                0        100 g       381      0.1g           NaN
# Nuts, pecans              1        100 g       691       72g          6.2g
# Eggplant, raw             2        100 g        25      0.2g           NaN
# Teff, uncooked            3        100 g       367      2.4g          0.4g
# Sherbet, orange           4        100 g       144        2g          1.2g
#
#                 cholesterol    sodium  choline     folate folic_acid  ...  \
# name                                                                  ...
# Cornstarch                0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...
# Nuts, pecans              0   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...
# Eggplant, raw             0   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...
# Teff, uncooked            0  12.00 mg  13.1 mg          0          0  ...
# ...

# %%
df
# Out:
#     age  weight  height
# 0  12.0   22.20    1.72
# 1  12.0   55.60    1.74
# 2  15.0   78.90    1.91
# 3  47.0   88.88    1.54

# %%
df.rename(index={0:'Pikachu'})
# Out:
#           age  weight  height
# Pikachu  12.0   22.20    1.72
# 1        12.0   55.60    1.74
# 2        15.0   78.90    1.91
# 3        47.0   88.88    1.54

# %%
df = df.rename(columns={'weight':'weight in kg'})

# %%
df
# Out:
#     age  weight in kg  height
# 0  12.0         22.20    1.72
# 1  12.0         55.60    1.74
# 2  15.0         78.90    1.91
# 3  47.0         88.88    1.54

# %%
df = df.rename(columns={'height':'height in m'})

# %%
df
# Out:
#     age  weight in kg  height in m
# 0  12.0         22.20         1.72
# 1  12.0         55.60         1.74
# 2  15.0         78.90         1.91
# 3  47.0         88.88         1.54
