# %%
import pandas as pd
import numpy as np

# %%
# Reading data

# %%
nutrition.head()
# Out:
#               name serving_size  calories total_fat saturated_fat cholesterol  \
# 0       Cornstarch        100 g       381      0.1g           NaN           0
# 1     Nuts, pecans        100 g       691       72g          6.2g           0
# 2    Eggplant, raw        100 g        25      0.2g           NaN           0
# 3   Teff, uncooked        100 g       367      2.4g          0.4g           0
# 4  Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#      sodium  choline     folate folic_acid  ...      fat  \
# 0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3  12.00 mg  13.1 mg          0          0  ...   2.38 g
# 4  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# ...

# %%
nutrition.sample()
# Out:
#                                                    name serving_size  \
# 7661  Beef, braised, cooked, choice, trimmed to 1/8"...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium   choline  \
# 7661       298       19g          8.2g       107mg  46.00 mg  109.2 mg
#
#         folate folic_acid  ...      fat saturated_fatty_acids  \
# 7661  9.00 mcg   0.00 mcg  ...  19.47 g               8.219 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 7661                     8.388 g                     0.720 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 7661               107.00 mg   0.0 g  0.95 g  0.00 mg     0.00 mg  51.58 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample(random_state=12)
# Out:
#                                                  name serving_size  calories  \
# 3713  Thuringer, pork, beef, summer sausage, cervelat        100 g       362
#
#      total_fat saturated_fat cholesterol      sodium  choline    folate  \
# 3713       30g           12g        74mg  1300.00 mg  78.9 mg  2.00 mcg
#
#      folic_acid  ...      fat saturated_fatty_acids  \
# 3713   0.00 mcg  ...  30.43 g              11.510 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 3713                    12.970 g                     1.200 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 3713                74.00 mg   0.0 g  3.63 g  0.00 mg     0.00 mg  45.18 g
#
# [1 rows x 76 columns]

# %%
nutrition.sample(n=7)
# Out:
#                                                    name serving_size  \
# 4810  Beef, raw, all grades, separable lean only, wh...        100 g
# 2449              Egg rolls, heated, refrigerated, pork        100 g
# 4359  KELLOGG'S EGGO Lowfat Blueberry Nutri-Grain Wa...        100 g
# 8530  Beef, raw, choice, trimmed to 0" fat, separabl...        100 g
# 7434  Cereals, without salt, cooked with water, whol...        100 g
# 1219                           Cucumber, raw, with peel        100 g
# 7402  Pasta, ANCIENT HARVEST, cooked, corn flour and...        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium  choline  \
# 4810       155      7.4g          2.6g        62mg   79.00 mg  86.5 mg
# 2449       222      7.2g          1.6g        14mg  407.00 mg  40.4 mg
# 4359       208      2.8g          0.4g           0  591.00 mg        0
# 8530       132      4.4g          1.4g        68mg   65.00 mg        0
# ...

# %%
nutrition.sample(frac=0.01)
# Out:
#                                                    name serving_size  \
# 3341           PEPPERIDGE FARM, Hamburger Buns w/Sesame        100 g
# 6848  English muffins, without calcium propionate (i...        100 g
# 247                                 Pepper, raw, banana        100 g
# 7499  Beef, braised, cooked, all grades, trimmed to ...        100 g
# 8182  Beef, grilled, cooked, all grades, trimmed to ...        100 g
# ...                                                 ...          ...
# 6649  Infant formula, ready-to-feed, PROTECT PLUS, G...        100 g
# 6426  PREGO Pasta, ready-to-serve, Organic Tomato an...        100 g
# 6056  Fast foods, with condiments, triple patty, lar...        100 g
# 3890     Beans, canned, mature seeds, all types, kidney        100 g
# 6613  Chicken, raw, with added solution, meat and sk...        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium   choline  \
# ...

# %%
nutrition.size
# Out:
# 667964

# %%
# sample with replacements

# %%
# with or without replacement

# %%
nutrition.sample(3,replace=True)
# Out:
#                                                    name serving_size  \
# 4049      KEEBLER, Oatmeal, Fudge Stripes, FUDGE SHOPPE        100 g
# 5724  CAMPBELL'S HEALTHY REQUEST, condensed, Cream o...        100 g
# 3173         Babyfood, dry, with honey, oatmeal, cereal        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium choline  \
# 4049       478       24g           15g           0  367.00 mg       0
# 5724        55      1.7g          0.3g           0  327.00 mg       0
# 3173       391        7g           NaN           0   47.00 mg       0
#
#          folate folic_acid  ...      fat saturated_fatty_acids  \
# 4049  33.00 mcg          0  ...  23.80 g              14.700 g
# 5724          0          0  ...   1.70 g               0.330 g
# 3173  35.00 mcg   0.00 mcg  ...   7.00 g                     0
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 4049                     3.100 g                     5.200 g
# ...

# %%
nutrition.sample(3,replace=False)
# Out:
#                                                    name serving_size  \
# 4062      SILK Vanilla soy yogurt (single serving size)        100 g
# 2664                Gravy, fat free, turkey, CAMPBELL'S        100 g
# 7706  Beef, raw, select, trimmed to 1/8" fat, separa...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# 4062        88      1.8g           NaN           0  12.00 mg        0
# 2664        33        0g           NaN         8mg         0        0
# 7706       144      5.3g          2.2g        59mg  57.00 mg  58.9 mg
#
#         folate folic_acid  ...     fat saturated_fatty_acids  \
# 4062         0          0  ...  1.76 g               0.000 g
# 2664         0          0  ...  0.00 g               0.000 g
# 7706  4.00 mcg   0.00 mcg  ...  5.34 g               2.152 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 4062                           0                           0
# ...

# %%
# weighted sampling

# %%
weights = pd.Series(data = [10,10,10,1,2], index=[7,17,29,6,5])

# %%
weights
# Out:
# 7     10
# 17    10
# 29    10
# 6      1
# 5      2
# dtype: int64

# %%
nutrition.sample(n=3, weights = weights)
# Out:
#                       name serving_size  calories total_fat saturated_fat  \
# 5         Cauliflower, raw        100 g        25      0.3g          0.1g
# 7        Lamb, raw, ground        100 g       282       23g           10g
# 29  Nuts, dried, pine nuts        100 g       673       68g          4.9g
#
#    cholesterol    sodium  choline     folate folic_acid  ...      fat  \
# 5            0  30.00 mg  44.3 mg  57.00 mcg   0.00 mcg  ...   0.28 g
# 7         73mg  59.00 mg  69.3 mg  18.00 mcg   0.00 mcg  ...  23.41 g
# 29           0   2.00 mg  55.8 mg  34.00 mcg   0.00 mcg  ...  68.37 g
#
#    saturated_fatty_acids monounsaturated_fatty_acids  \
# 5                0.130 g                     0.034 g
# 7               10.190 g                     9.600 g
# 29               4.899 g                    18.764 g
#
#    polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 5                      0.031 g                 0.00 mg   0.0 g  0.76 g
# ...
