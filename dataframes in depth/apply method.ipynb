# %%
import numpy as np

# %%
import pandas as pd

# %%
players = pd.read_csv(r"C:\Users\97798\Desktop\Pandas\dataframes in depth\soccer.csv")

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
def round_floats(x):
    if x.dtype == np.float64:
        return round(x)
    
    return x

# %%
players.select_dtypes(float).transform(round_floats)
# Out:
#      market_value  fpl_value
# 0            65.0       12.0
# 1            50.0       10.0
# 2             7.0        6.0
# 3            20.0        8.0
# 4            22.0        6.0
# ..            ...        ...
# 460           5.0        4.0
# 461           7.0        4.0
# 462           4.0        4.0
# 463           1.0        4.0
# 464          10.0        6.0
#
# [465 rows x 2 columns]

# %%
# apply as aggregate

# %%
players.agg('mean')
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_14484\3820880281.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   players.agg('mean')
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
players.apply('mean')
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_14484\1670461102.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   players.apply('mean')
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
# fliiping the axis param

# %%
players.apply('mean',axis =1)
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_14484\3177368968.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   players.apply('mean',axis =1)
# 0      392.333333
# 1      388.208333
# 2      143.708333
# 3      214.875000
# 4       91.916667
#           ...
# 460     31.875000
# 461     24.791667
# 462     23.750000
# 463     39.875000
# 464     24.708333
# Length: 465, dtype: float64

# %%
players.loc[460,:].apply('mean')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [170], in <cell line: 1>()
# ----> 1 players.loc[460,:].apply('mean')
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1080, in SeriesApply.apply(self)
#    1076     return self.apply_multiple()
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
# -> 1080     return self.apply_str()
# ...

# %%
players.loc[460,[dtype != object for dtype in players.dtypes]]
# Out:
# age              21
# position_cat      2
# market_value    5.0
# page_views      288
# fpl_value       4.5
# fpl_points       38
# region            2
# new_foreign       0
# age_cat           1
# club_id          20
# big_club          0
# new_signing       1
# Name: 460, dtype: object

# %%
# elementwise apply method

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
inflation = 1.02

# %%
mini_df = players.loc[:,['market_value','fpl_value']]

# %%
comini_df * inflation
# Out:
#      market_value  fpl_value
# 0           66.30      12.24
# 1           51.00       9.69
# 2            7.14       5.61
# 3           20.40       7.65
# 4           22.44       6.12
# ..            ...        ...
# 460          5.10       4.59
# 461          7.14       4.59
# 462          4.59       4.59
# 463          1.02       4.59
# 464         10.20       5.61
#
# [465 rows x 2 columns]

# %%
from datetime import datetime

counter = 0


def log_and_transform(x):
    global counter
    counter = counter+1
    if counter % 100 == 0:
        print(f'Its {datetime.now()} and I adjusted the {counter}th value')
    
    return x * inflation

# %%
import sys
sys.version
# Out:
# '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]'

# %%
mini_df.apply(log_and_transform)
# Out:
#      market_value  fpl_value
# 0           66.30      12.24
# 1           51.00       9.69
# 2            7.14       5.61
# 3           20.40       7.65
# 4           22.44       6.12
# ..            ...        ...
# 460          5.10       4.59
# 461          7.14       4.59
# 462          4.59       4.59
# 463          1.02       4.59
# 464         10.20       5.61
#
# [465 rows x 2 columns]

# %%
mini_df.apply(log_and_transform)
# Out:
#      market_value  fpl_value
# 0           66.30      12.24
# 1           51.00       9.69
# 2            7.14       5.61
# 3           20.40       7.65
# 4           22.44       6.12
# ..            ...        ...
# 460          5.10       4.59
# 461          7.14       4.59
# 462          4.59       4.59
# 463          1.02       4.59
# 464         10.20       5.61
#
# [465 rows x 2 columns]
