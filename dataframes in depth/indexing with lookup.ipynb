# %%
import numpy as np
import pandas as pd

# %%
players = pd.read_csv(r"C:\Users\97798\Desktop\Pandas\dataframes in depth\soccer.csv")

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.sample(10)
# Out:
#                   name         club  age position  position_cat  market_value  \
# 388          Eric Dier    Tottenham   23       DM             2          25.0
# 367       Modou Barrow      Swansea   24       RW             1           3.0
# 53        Tyrone Mings  Bournemouth   24       CB             3           5.0
# 44       Callum Wilson  Bournemouth   25       CF             1          10.0
# 318       Steven Davis  Southampton   32       CM             2           6.0
# 163      Davy Klaassen      Everton   24       AM             1          18.0
# 335          Lee Grant   Stoke+City   34       GK             4           1.0
# 104      Cesc Fabregas      Chelsea   30       CM             2          35.0
# 403       Jose Holebas      Watford   33       LB             3           2.0
# 148  Ramiro Funes Mori      Everton   26       CB             3          12.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region       nationality  \
# ...

# %%
players.lookup([440],['age'])
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_16548\1040395053.py:1: FutureWarning: The 'lookup' method is deprecated and will be removed in a future version. You can use DataFrame.melt and DataFrame.loc as a substitute.
#   players.lookup([440],['age'])
# array([19], dtype=int64)

# %%
players.loc[[4,100],['name','age']]
# Out:
#                   name  age
# 4    Laurent Koscielny   31
# 100  Cesar Azpilicueta   27

# %%
players.lookup([4,100],['name','age'])
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_16548\536911914.py:1: FutureWarning: The 'lookup' method is deprecated and will be removed in a future version. You can use DataFrame.melt and DataFrame.loc as a substitute.
#   players.lookup([4,100],['name','age'])
# array(['Laurent Koscielny', 27], dtype=object)

# %%
players.lookup([4,100],['age','name'])
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_16548\2458091080.py:1: FutureWarning: The 'lookup' method is deprecated and will be removed in a future version. You can use DataFrame.melt and DataFrame.loc as a substitute.
#   players.lookup([4,100],['age','name'])
# array([31, 'Cesar Azpilicueta'], dtype=object)

# %%
names = ['Petr Cech', 'Mesut Ozil','Alexis Sancho']

# %%
attributes = ['age','market_value','page_views']

# %%
players.lookup(names, attributes )
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_16548\401374950.py:1: FutureWarning: The 'lookup' method is deprecated and will be removed in a future version. You can use DataFrame.melt and DataFrame.loc as a substitute.
#   players.lookup(names, attributes )
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 players.lookup(names, attributes )
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4586, in DataFrame.lookup(self, row_labels, col_labels)
#    4583     raise ValueError("Row labels must have same size as column labels")
#    4584 if not (self.index.is_unique and self.columns.is_unique):
#    4585     # GH#33041
# -> 4586     raise ValueError("DataFrame.lookup requires unique index and columns")
#    4588 thresh = 1000
#    4589 if not self._is_mixed_type or n > thresh:
#
# ...

# %%
players.head()
# Out:
#                       club  age position  position_cat  market_value  \
# name
# Alexis Sanchez     Arsenal   28       LW             1          65.0
# Mesut Ozil         Arsenal   28       AM             1          50.0
# Petr Cech          Arsenal   35       GK             4           7.0
# Theo Walcott       Arsenal   28       RW             1          20.0
# Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#                    page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Alexis Sanchez           4329       12.0  17.10%         264       3
# Mesut Ozil               4395        9.5   5.60%         167       2
# Petr Cech                1529        5.5   5.90%         134       2
# Theo Walcott             2393        7.5   1.50%         122       1
# Laurent Koscielny         912        6.0   0.70%         121       2
#
#                       nationality  new_foreign  age_cat  club_id  big_club  \
# name
# ...

# %%
players.lookup(names,attributes)
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_16548\1714550247.py:1: FutureWarning: The 'lookup' method is deprecated and will be removed in a future version. You can use DataFrame.melt and DataFrame.loc as a substitute.
#   players.lookup(names,attributes)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 players.lookup(names,attributes)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4586, in DataFrame.lookup(self, row_labels, col_labels)
#    4583     raise ValueError("Row labels must have same size as column labels")
#    4584 if not (self.index.is_unique and self.columns.is_unique):
#    4585     # GH#33041
# -> 4586     raise ValueError("DataFrame.lookup requires unique index and columns")
#    4588 thresh = 1000
#    4589 if not self._is_mixed_type or n > thresh:
#
# ...
