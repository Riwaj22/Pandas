# %%
import numpy as np
import pandas as pd

# %%
players = pd.read_csv(r"C:\Users\97798\Desktop\soccer.csv")

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.sample(5)
# Out:
#                     name              club  age position  position_cat  \
# 105              Willian           Chelsea   28       RW             1
# 119  Patrick van Aanholt    Crystal+Palace   26       LB             3
# 338       Ryan Shawcross        Stoke+City   29       CB             3
# 306         Dwight Gayle  Newcastle+United   26       CF             1
# 452        James Collins          West+Ham   33       CB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 105          32.0        1165        7.0   9.00%         114       3
# 119           9.0         524        5.5   4.20%          98       2
# 338          11.0         281        5.0   1.00%          94       2
# 306          10.0        1351        6.5  11.40%           0       1
# 452           2.0         187        4.5   0.90%          69       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# ...

# %%
players[players.position== 'GK' ]
# Out:
#                      name               club  age position  position_cat  \
# 2               Petr Cech            Arsenal   35       GK             4
# 25      Emiliano Martinez            Arsenal   24       GK             4
# 26           David Ospina            Arsenal   28       GK             4
# 35            Artur Boruc        Bournemouth   37       GK             4
# 51          Adam Federici        Bournemouth   32       GK             4
# 55          Asmir Begovic        Bournemouth   30       GK             4
# 56           Niki Maenpaa  Brighton+and+Hove   32       GK             4
# 57            Mathew Ryan  Brighton+and+Hove   25       GK             4
# 78             Tom Heaton            Burnley   31       GK             4
# 102      Thibaut Courtois            Chelsea   25       GK             4
# 109       Willy Caballero            Chelsea   35       GK             4
# 121       Wayne Hennessey     Crystal+Palace   30       GK             4
# ...

# %%
players[(players.position == 'LB') & 
        (players.age>=25)
       ]
# Out:
#                       name               club  age position  position_cat  \
# 7            Nacho Monreal            Arsenal   31       LB             3
# 18            Kieran Gibbs            Arsenal   27       LB             3
# 34         Charlie Daniels        Bournemouth   30       LB             3
# 62             Gaetan Bong  Brighton+and+Hove   29       LB             3
# 65          Markus Suttner  Brighton+and+Hove   30       LB             3
# 82            Stephen Ward            Burnley   31       LB             3
# 99   Marcos Alonso Mendoza            Chelsea   26       LB             3
# 119    Patrick van Aanholt     Crystal+Palace   26       LB             3
# 134            Pape Souare     Crystal+Palace   27       LB             3
# 138        Leighton Baines            Everton   32       LB             3
# 168             Chris Lowe       Huddersfield   28       LB             3
# 175           Scott Malone       Huddersfield   26       LB             3
# ...

# %%
players[(players.position == 'LB') & 
        (players.age <=25) &
        (players.market_value >=10)
       ]
# Out:
#                name               club  age position  position_cat  \
# 29   Sead Kolasinac            Arsenal   24       LB             3
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
# 389      Ben Davies          Tottenham   24       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 29           15.0         618        6.0   6.90%           0       2
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
# 389          12.0         396        5.5   1.80%          90       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 29       Bosnia            1        2        1         1            0
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0
# ...

# %%
# players excluding Arsenal and Tottenham

players[(players.position == 'LB') & 
        (players.age <=25) &
        (players.market_value >=10) & 
        ~(players.club.isin(['Arsenal','Tottenham']))
       ]
# Out:
#                name               club  age position  position_cat  \
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0

# %%
# new_target : Arsenal Rb and chelsea Gk

# %%
arsenal_player = players[players.club == 'Arsenal']

# %%
arsenal_rb = arsenal_player[arsenal_player.position == 'RB']
arsenal_rb
# Out:
#                name     club  age position  position_cat  market_value  \
# 5   Hector Bellerin  Arsenal   22       RB             3          30.0
# 27   Carl Jenkinson  Arsenal   25       RB             3           5.0
#
#     page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 5         1675        6.0  13.70%         119       2       Spain
# 27         561        4.5   0.40%           2       1     England
#
#     new_foreign  age_cat  club_id  big_club  new_signing
# 5             0        2        1         1            0
# 27            0        3        1         1            0

# %%
# chelsea GK

# %%
chelsea_player = players[players.club == 'Chelsea']

# %%
chelsea_player
# Out:
#                       name     club  age position  position_cat  market_value  \
# 96             Eden Hazard  Chelsea   26       LW             1         75.00
# 97             Diego Costa  Chelsea   28       CF             1         50.00
# 98             Gary Cahill  Chelsea   31       CB             3         16.00
# 99   Marcos Alonso Mendoza  Chelsea   26       LB             3         25.00
# 100      Cesar Azpilicueta  Chelsea   27       RB             3         30.00
# 101                  Pedro  Chelsea   29       RW             1         28.00
# 102       Thibaut Courtois  Chelsea   25       GK             4         40.00
# 103             David Luiz  Chelsea   30       CB             3         30.00
# 104          Cesc Fabregas  Chelsea   30       CM             2         35.00
# 105                Willian  Chelsea   28       RW             1         32.00
# 106           Victor Moses  Chelsea   26       RM             2         18.00
# ...

# %%
chelsea_gk = arsenal_player[arsenal_player.position == 'GK']
chelsea_gk
# Out:
#                  name     club  age position  position_cat  market_value  \
# 2           Petr Cech  Arsenal   35       GK             4           7.0
# 25  Emiliano Martinez  Arsenal   24       GK             4           1.0
# 26       David Ospina  Arsenal   28       GK             4           7.0
#
#     page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 2         1529        5.5   5.90%         134       2  Czech Republic
# 25         372        4.0   4.20%           8       3       Argentina
# 26         544        5.0   0.20%           2       3        Colombia
#
#     new_foreign  age_cat  club_id  big_club  new_signing
# 2             0        6        1         1            0
# 25            0        2        1         1            0
# 26            0        4        1         1            0
