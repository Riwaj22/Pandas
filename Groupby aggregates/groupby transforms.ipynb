# %%
import numpy as np
import pandas as pd

# %%
# convert raw global sales to within genre standard scores

# %%
games.head(10)
# Out:
#                              Name Platform    Year    Genre  \
# 0              Kinect Adventures!     X360  2010.0     Misc
# 1              Grand Theft Auto V      PS3  2013.0   Action
# 2              Grand Theft Auto V     X360  2013.0   Action
# 3  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4         Call of Duty: Black Ops     X360  2010.0  Shooter
# 5       Call of Duty: Black Ops 3      PS4  2015.0  Shooter
# 6      Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 7      Call of Duty: Black Ops II     X360  2012.0  Shooter
# 8  Call of Duty: Modern Warfare 2     X360  2009.0  Shooter
# 9  Call of Duty: Modern Warfare 3      PS3  2011.0  Shooter
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1    Take-Two Interactive      7.01      9.27      0.97         4.14
# 2    Take-Two Interactive      9.63      5.31      0.06         1.38
# ...

# %%
games_relative = games.loc[:,['Name', 'Genre', 'Platform','Global_Sales']]

# %%
games_relative
# Out:
#                                 Name         Genre Platform  Global_Sales
# 0                 Kinect Adventures!          Misc     X360         21.82
# 1                 Grand Theft Auto V        Action      PS3         21.40
# 2                 Grand Theft Auto V        Action     X360         16.38
# 3     Call of Duty: Modern Warfare 3       Shooter     X360         14.76
# 4            Call of Duty: Black Ops       Shooter     X360         14.64
# ...                              ...           ...      ...           ...
# 3138                  Bound By Flame  Role-Playing     X360          0.01
# 3139                    Mighty No. 9      Platform     XOne          0.01
# 3140              Resident Evil 4 HD       Shooter     XOne          0.01
# 3141   Farming 2017 - The Simulation    Simulation      PS4          0.01
# 3142               Rugby Challenge 3        Sports     XOne          0.01
#
# [3143 rows x 4 columns]

# %%
games_relative.set_index(['Name', 'Platform']).groupby('Genre').transform(lambda x: (x-x.mean())/x.std()).sort_values('Global_Sales', ascending = False)
# Out:
#                                                              Global_Sales
# Name                                               Platform
# Grand Theft Auto V                                 PS3          13.831175
# Kinect Adventures!                                 X360         13.814162
# Grand Theft Auto V                                 X360         10.468663
# Gran Turismo 5                                     PS3           9.159261
# Grand Theft Auto V                                 PS4           7.521441
# ...                                                                   ...
# Dragon Ball Z for Kinect                           X360         -0.872762
# Nitroplus Blasterz: Heroines Infinite Duel         PS3          -0.872762
# Battle Fantasia                                    PS3          -0.872762
# Sakigake!! Otokojuku - Nihon yo, Kore ga Otoko ... PS3          -0.872762
# The Talos Principle                                PS4          -0.899346
#
# ...

# %%
ps3 = games[games.Platform == 'PS3'].loc[:,['Genre','Name', 'EU_Sales','Global_Sales']]

# %%
ps3.groupby('Genre').apply(lambda x: 'solid' if x.EU_Sales.sum() > 5 else 'weak')
# Out:
# Genre
# Action          solid
# Adventure       solid
# Fighting        solid
# Misc            solid
# Platform        solid
# Puzzle           weak
# Racing          solid
# Role-Playing    solid
# Shooter         solid
# Simulation       weak
# Sports          solid
# Strategy         weak
# dtype: object
