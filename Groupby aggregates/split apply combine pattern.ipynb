# %%
import numpy as np
import pandas as pd

# %%
sales_url = 'https://andybek.com/pandas-games'

# %%
games = pd.read_csv(sales_url)

# %%
games.head(10)
# Out:
#                              Name Platform    Year    Genre  \
# 0              Kinect Adventures!     X360  2010.0     Misc
# 1              Grand Theft Auto V      PS3  2013.0   Action
# 2              Grand Theft Auto V     X360  2013.0   Action
# 3  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4         Call of Duty: Black Ops     X360  2010.0  Shooter
# 5       Call of Duty: Black Ops 3      PS4  2015.0  Shooter
# 6      Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 7      Call of Duty: Black Ops II     X360  2012.0  Shooter
# 8  Call of Duty: Modern Warfare 2     X360  2009.0  Shooter
# 9  Call of Duty: Modern Warfare 3      PS3  2011.0  Shooter
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1    Take-Two Interactive      7.01      9.27      0.97         4.14
# 2    Take-Two Interactive      9.63      5.31      0.06         1.38
# ...

# %%
games.sum()
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_8928\1599516262.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   games.sum()
# Name            Kinect Adventures!Grand Theft Auto VGrand Thef...
# Platform        X360PS3X360X360X360PS4PS3X360X360PS3PS3X360PS4...
# Year                                                    6210506.0
# Genre           MiscActionActionShooterShooterShooterShooterSh...
# NA_Sales                                                   1173.3
# EU_Sales                                                   793.64
# JP_Sales                                                   107.06
# Other_Sales                                                282.75
# Global_Sales                                              2356.96
# dtype: object

# %%
# 1. seperate the data

# %%
games[games.Platform == 'X360']
# Out:
#                                      Name Platform    Year         Genre  \
# 0                      Kinect Adventures!     X360  2010.0          Misc
# 2                      Grand Theft Auto V     X360  2013.0        Action
# 3          Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 4                 Call of Duty: Black Ops     X360  2010.0       Shooter
# 7              Call of Duty: Black Ops II     X360  2012.0       Shooter
# ...                                   ...      ...     ...           ...
# 3127                            MotoGP 15     X360  2015.0        Racing
# 3128  DoDonPachi Daifukkatsu: Black Label     X360  2011.0       Shooter
# 3130             Dragon Ball Z for Kinect     X360  2012.0      Fighting
# 3135          Metal Gear Solid HD Edition     X360  2011.0        Action
# 3138                       Bound By Flame     X360  2014.0  Role-Playing
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
games[games.Platform == 'PS3']
# Out:
#                                                    Name Platform    Year  \
# 1                                    Grand Theft Auto V      PS3  2013.0
# 6                            Call of Duty: Black Ops II      PS3  2012.0
# 9                        Call of Duty: Modern Warfare 3      PS3  2011.0
# 10                              Call of Duty: Black Ops      PS3  2010.0
# 14                                       Gran Turismo 5      PS3  2010.0
# ...                                                 ...      ...     ...
# 3124                        Hyperdimension Neptunia mk2      PS3  2011.0
# 3125  Shin Koihime Musou: Otome Taisen * Sangokushi ...      PS3  2014.0
# 3129                                Muv-Luv Alternative      PS3  2012.0
# 3132                           Akatsuki no Goei Trinity      PS3  2012.0
# 3136                                    Battle Fantasia      PS3  2008.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# 2.calculate sum

# %%
games[games.Platform == 'X360'].sum(numeric_only=True)
# Out:
# Year            2482205.00
# NA_Sales            601.05
# EU_Sales            280.58
# JP_Sales             12.43
# Other_Sales          85.54
# Global_Sales        979.96
# dtype: float64

# %%
games[games.Platform == 'PS3'].sum(numeric_only=True)
# Out:
# Year            2622109.00
# NA_Sales            392.26
# EU_Sales            343.71
# JP_Sales             79.99
# Other_Sales         141.93
# Global_Sales        957.84
# dtype: float64

# %%
games[games.Platform == 'X360'].sum(numeric_only=True) + games[games.Platform == 'PS3'].sum(numeric_only=True)
# Out:
# Year            5104314.00
# NA_Sales            993.31
# EU_Sales            624.29
# JP_Sales             92.42
# Other_Sales         227.47
# Global_Sales       1937.80
# dtype: float64

# %%
# find the total sales by region for x360 and ps3

# %%
games.groupby('Platform').sum().drop(labels='Year', axis =1)
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# PS3         392.26    343.71     79.99       141.93        957.84
# PS4          96.80    123.70     14.30        43.36        278.10
# X360        601.05    280.58     12.43        85.54        979.96
# XOne         83.19     45.65      0.34        11.92        141.06

# %%
games.groupby('Platform').mean().drop(labels='Year', axis =1)
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# PS3       0.295154  0.258623  0.060188     0.106795      0.720722
# PS4       0.288095  0.368155  0.042560     0.129048      0.827679
# X360      0.475138  0.221802  0.009826     0.067621      0.774672
# XOne      0.390563  0.214319  0.001596     0.055962      0.662254

# %%
games.groupby('Platform').median().drop(labels='Year', axis =1)
# Out:
#           NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# PS3           0.12      0.07      0.01         0.03          0.28
# PS4           0.07      0.08      0.02         0.03          0.22
# X360          0.17      0.06      0.00         0.02          0.28
# XOne          0.15      0.07      0.00         0.02          0.24

# %%
# Groupby object

# %%
games.groupby('Platform').sum()
# Out:
#                Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# PS3       2622109.0    392.26    343.71     79.99       141.93        957.84
# PS4        677042.0     96.80    123.70     14.30        43.36        278.10
# X360      2482205.0    601.05    280.58     12.43        85.54        979.96
# XOne       429150.0     83.19     45.65      0.34        11.92        141.06

# %%
len(games.groupby('Platform'))
# Out:
# 4
