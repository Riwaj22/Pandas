# %%
import numpy as np
import pandas as pd

# %%
players.head(5)
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
# find all players who are english

# %%
english_players = players[players.nationality == 'England']

# %%
english_players
# Out:
#                         name      club  age position  position_cat  \
# 3               Theo Walcott   Arsenal   28       RW             1
# 12   Alex Oxlade-Chamberlain   Arsenal   23       RM             2
# 13   Alex Oxlade-Chamberlain   Arsenal   23       RM             2
# 14             Jack Wilshere   Arsenal   25       CM             2
# 18              Kieran Gibbs   Arsenal   27       LB             3
# ..                       ...       ...  ...      ...           ...
# 450               Mark Noble  West+Ham   30       CM             2
# 453             Andy Carroll  West+Ham   28       CF             1
# 455          Aaron Cresswell  West+Ham   27       LB             3
# 462                Sam Byram  West+Ham   23       RB             3
# 463          Ashley Fletcher  West+Ham   21       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 3            20.0        2393        7.5   1.50%         122       1
# ...

# %%
# their market value is more than twice the average market value in the league

# %%
mean_value = players.market_value.mean()

# %%
players[players.market_value >= 2*mean_value].name
# Out:
# 0         Alexis Sanchez
# 1             Mesut Ozil
# 5        Hector Bellerin
# 8       Shkodran Mustafi
# 10          Granit Xhaka
#              ...
# 386    Toby Alderweireld
# 387       Victor Wanyama
# 388            Eric Dier
# 390           Danny Rose
# 396          Erik Lamela
# Name: name, Length: 65, dtype: object

# %%
# they either have more than 4000 views or a new signing but not both

# %%
players.page_views
# Out:
# 0      4329
# 1      4395
# 2      1529
# 3      2393
# 4       912
#        ...
# 460     288
# 461     199
# 462     198
# 463     412
# 464     214
# Name: page_views, Length: 465, dtype: int64

# %%
players.new_signing
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 460    1
# 461    1
# 462    0
# 463    1
# 464    0
# Name: new_signing, Length: 465, dtype: int64

# %%
players[(players.page_views > 4000) ^ (players.new_signing ==1)].name
# Out:
# 0           Alexis Sanchez
# 1               Mesut Ozil
# 8         Shkodran Mustafi
# 21             Rob Holding
# 24             Lucas Perez
#               ...
# 448             Andre Ayew
# 457       Sofiane Feghouli
# 460    Edimilson Fernandes
# 461         Arthur Masuaku
# 463        Ashley Fletcher
# Name: name, Length: 72, dtype: object
